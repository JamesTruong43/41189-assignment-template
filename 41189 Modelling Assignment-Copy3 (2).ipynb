# %% [markdown]
# # **41189 Modelling Assignment — Group 9**
#
#  Topic: Strategies to contain COVID-19
#
#  Group members:
#
#  - James Truong (13868738)
#  - Ali Khalife (12746398)
#  - Harrison Andrew
#  - Lawrence Roqueza(13903570)

# %% [markdown]
# # Introduction

# %% [markdown]
# ## State the problem, why it is important/relevant to you and/or more broadly to society

# %% [markdown]
# The problem is what strategies can we implement to contain COVID 19, it is important to society as we need to be prepared and aware of what COVID19 is capable of. We are currently dealing with the second wave of cases.

# %% [markdown]
# # Context, background information, justification

# %% [markdown]
# ## Research and review literature, news, digital media, drivers and how the problem is being addressed by academia, industry, government, etc.

# %% [markdown]
# ACADEMIA - During the emergence of the Covid-19 pandemic, the Australian government have responded promptly to implement mitigation strategies among communities. Australian Academic staff have conducted research to examine the attitudes and beliefs of Australian adults towards the pandemic, and willingness and capacity to engage with these mitigation measures. Moreover, academia has also emphasised on the importance of mental health and effects is has, thus placing focus on related services.

# %% [markdown]
# GENERAL PUBLIC - Research suggests that members of the public have been inundated with messages about hygiene and social distancing. However, our results indicate that a continued focus on supporting community understanding of the rationale for these strategies, as well as instilling community confidence in their ability to adopt or sustain the recommendations is necessary.

# %% [markdown]
# GOVERNMENT - After the Government’s decision to ease Covid-19 restrictions placed, majority of this decision with notion to stimulate Australia’s economic status, which has had a decline and stagnant forecasting by the RBA. A number of people have issued worries of a regression or a “second wave”. To combat this threat, the government has encouraged members of the public to wear a mask when one is not able to social distance.

# %% [markdown]
# ## Identify the system + stakeholders. For this, you will need to construct a “rich picture” that captures the essential elements.

# %% [markdown]
# The stakeholders for containing COVID19 include the Government, the People, Medical Experts.

# %% [markdown]
# ![richpic.png](attachment:richpic.png)

# %% [markdown]
# ## Identify current models or prevailing frames that are being used to address the problem

# %% [markdown]
# Broadcast Model

# %% [markdown]
# Standing Ovation Model is currently being used by people/communites. By providing the choice of wearing face masks.

# %% [markdown]
# The SRI Model is currently being used to determine the spread within a community. This model is based on estimation
# probability, based on contact, spread, death, recovery and basic reproduction numbers. when calculating the spread of COVID 19,
# the SRI Model has derived two thresholds which could affects the outcomes of results.

# %% [markdown]
# ## Discuss how prevailing models/frames are preventing the problem from being fully addressed or solved

# %% [markdown]
# # Conceptual Models

# %% [markdown]
# ## Based on your self-study of the supermarket of models, explain the three models that you have chosen to look at the problem

# %% [markdown]
# Standing Ovation Model - Wearing a Mask - The standing ovation model suggests that a large peer effect can occur based purely off of people following the actions of others.

# %% [markdown]
# The SRI model which is used to categorise the population into three groups susceptible, infectious, and removed, people who are considered susceptible are the ones who are not been infected.
#
#
# Susceptible —> Infectious
#
# Infectious —> Removed
#
# Where the change rate of the removed group at a given time, only depends on the ‘Infectious individuals’ ratio at that given time.

# %% [markdown]
# The broadcast model captures the spread of ideas, rumours and information through television, radio, social media or internet. It captures the process undertaken by sources such as governments, corporations and newspapers when spreading information.

# %% [markdown]
# ## Explain how each of the three models works (brief) and how it will be applied in your case.

# %% [markdown]
# # Standing Ovation

# %% [markdown]
# The standing ovation model forces a binary decision-making process where an individual has two options, either join in and adhere to a certain action, or don’t. Individuals are influenced socially by people of various degrees of sophistication who received information via a network. At the centre of this model lies one key explanation: macro behaviour caused by micro motives.
#
#
#
# Wearing masks is an almost certain way of containing Covid-19. A standing ovation model can be applied because if more people wear masks, the more likely it is that others will too. Analogously, depending on the size and shape of the auditorium, in this case the environment in which someone lives, it will greatly affect the likelihood of deciding to wear a mask. For example, living in the city where there is more variance in social dynamic will lend toward a higher inclination for someone to wear a mask. Conversely, living in a rural area where the community has an overarching, like-minded attitude causes a lower variance and therefore a lower chance of wearing a mask.
#
#
#
# Also, the attitude towards Covid-19 will impact the chances of wearing a mask the same way the quality of the performance affects the standing ovation. If everyone took the virus extremely seriously then there would be a very low ‘error function’, which is the judgement of the signal, in this case a worldwide pandemic. The ‘error function’ or error rate, can vary based on attitude, knowledge or education. For example, someone who is stubborn and does not understand the benefits of masks in containing airborne particles will have a high error rate and therefore be unlikely to wear a mask.

# %% [markdown]
# # SIR Model

# %% [markdown]
# In our case study it can be used by stakeholders that we mentioned  several ways and techniques and as government and health organisation struggling in finding a vaccine then a good strategy to containing the spread of COVID-19 is to use available solution to use a ‘Time Dependent SIR model’, by tracking 2 times series with the main purpose to find the undetectable cases of COVID-19 that might help to spread it faster.

# %% [markdown]
# # Broadcast Model

# %% [markdown]
# The broadcast models goal is to increase the amount of informed people each day. Through an array of media outlets, governments and health organisations are able to share health-related information to reduce the number of cases. If no one broadcasted the outbreak of Covid 19, then the actions undertaken by governments, health care systems and health professionals would have resulted in numerous preventable cases and even deaths. Examples of broadcasted information that helped contain the virus are hygiene directions, national and state-wide lockdowns and Covid 19 hotspots that should be avoided.
#
#
#
# A negative response can come from broadcasting with the emergence of rumours and fake news. False information of the virus has caused worldwide negligence with rumours that the pandemic is a hoax, that it was manufactured in a lab, that only the elderly can get it and it has even caused attacks towards Chinese people and their culture. Social media platforms are at the forefront of the misleading information and display a portion of the negative side of broadcast models.
#
#
#
# Also, television, radio and other media platforms are largely responsible for the alarmism that people have undertaken for example ‘panic buying’ in supermarkets. However, it is this same alarmism that causes people to care about preventing the spread of the pandemic.

# %% [markdown]
# ## Describe any data sources (real or hypothetical) that are needed to construct the three models. Use illustrative drawings and diagrams where possible

# %% [markdown]
# # Standing Ovation

# %% [markdown]
# It is difficult to obtain objective numerical data because this model is based heavily on social pressure.
#
# We can calculate the social pressure via the formula:
#
#
#
# Social Pressure = [(1-Neighbour weight) x Funnel Pressure] + (Neighbour weight x Neighbour pressure)
#
#
#
# Neighbour weight = Importance of that person e.g. family, friends, high social status
#
# Funnel pressure = How many people the person may see in a given time
#
# Neighbour pressure = How many people wearing masks that the person may see in a given time
#
#
#
# If the social pressure is larger than a fixed threshold then the person will wear a mask.

# %% [markdown]
# # SIR Model

# %% [markdown]
# The first one is the transmission rate at time (t) if we set (t) as the time measured in days as an independent variable, and the recovering rate (t), using data provided from the health department we can ensure that the prediction errors per day have decreased and the total predicted number of COVID confirmed cases is predicted more precise.
#
# Turning Point:
#
# For example, where we can precisely predict how (Transmission Rate/day < Recovering Rate/day) and then (reproduction no. will be less than 1) R0 < 1
#
#
#
# Also another example going further with the SIR model we can consider a population N, if a person gets infected then this person becomes ‘infectious’ immediately and has to remain for certain time known as ‘decay rate’ of (Y) (The Removal Rate). And in reverse the (Y^-1) is the average infectious days taken by the ‘infictious person’ to transmit the virus to the group before the virus is being removed, the parameter known as (B) is the ‘effective contact rate, presenting the average number product of exposures per time unit (T), and (u) the likelihood infection on every exposure occasion.
#
#
#
# (B) = (T) X (U)
#
#
#
# Considering the same closed population (N) in the above scenario, with the below representations
#
#
#
# S(t) : susceptible
#
# I(t): Infectious
#
# R(t): Removed
#
#
#
# We can assume the total population at time (t) is as follows:
#
#
#
# N(t) = S(t) + I(t) + R(t)
#
#
#
# Again assuming that the epidemic start point we had (S(0), I(0), R(0))= (N-1, 1, 0) which means that in the N population there is one ‘Infectious Individual’ with ‘No Removal’ then the number of ‘Susceptible Individuals’ will decrease symmetrically by:
#
#
#
# D(S)/D(t) = B *  [  S(t). I(t) / N)  ].

# %% [markdown]
# # Broadcast Model

# %% [markdown]
# We can link a number of models when ‘Broadcasting’ communicates about COVID-19, such models can be used to announce some strategies to control the spread of this virus as well as to quantify people’s role responding to the outbreak to take protective actions;
#
#
#
#
#
# There are two cases here its when MEDIA:
#
#
#
# Increases attention on the virus impact and self-protection procedures.
#
# Decreases its attention on the virus impact and self-protection procedures.
#
#
#
#
#
# Choice (a) applies in our case study and this is from what we experienced as well , as when media increased the attention on the outbreak by alerting on increasing the use of Hygiene and self-protection procedures, this has generated large interest and created awareness to people on how to practice social distancing, waring face masks, washing hands, and using hygiene.
#
#
#
#
#
# in our case study if we divide the population (Npop) into two groups of people, those who are infected and informed about the infection denoted by (It) and (St) who are the remaining people know as the susceptible people =>  Npop = It+ St.
#
#  So media can play a crucial role containing the virus, especially when the probability of the increasing or decreasing the spread is affected by (Broadcasting) or the media coverage and here comes the equation of the informed people at a given time gives us (the number informed people in the previous period) + (the probability that a susceptible person hears of the information multiplying it by (the number of susceptible people):
#
#
#
#
#
# It+1 = It+ (Pbroad .St)
#
#
#
# So estimating the population size if applying this formula using an example of a city of 1 million residents, in the second day of the virus spread, and the media announces the first day, the number of informed people of the first people might reach 400,000 (40%) and the probability that a susceptible person hears of the information will be (20%) 300,000 and the actual susceptible people was 10% (100,000), as seen the number of informed people will increase over time according to the equation
#
#
#
#
#
# Modelling data from the broadcast:
#
# Period 1: I1 = 400,000 = Pbroad · Npop
#
# Period 2: I2 = 700,000 = 400,000 + Pbroad · (Npop – 400,000)

# %% [markdown]
# # Implementation

# %% [markdown]
# ## Describe the mathematical and/or statistical implementation of your three models. This should be done using Python code.

# %% [markdown]
# # Standing Ovation Model

# %%
import numpy as np
from numba import njit
import matplotlib.pyplot as plt
# %matplotlib inline

# Set audience size
N = 25
M = 50

# Fix performance quality as 50%
P = 0.5

# Fix Performance threshold
T = 0.6

# Fix seed
np.random.seed(123)

# Fix all audience as seated (0) initially
audience = np.zeros((N, M))

# Set error functions for audience members
epsilon = np.random.random((N, M)) - 0.5

# Fix number of timesteps
T_steps = 100
Pct_Hold = np.zeros(T_steps+1)

# Fix social pressure threshold
Pressure_T = 0.5

# Fix neighbour weight
N_weight = 1

# Fix probaility of spontaneous standing
delta = 0.75

# Fix probability of spontaneous sitting
gamma = 0.75

# Calculate initial reactions to performance
@njit
def initial_stand(error, p, t):
    signal = p + error
    out = signal > t
    return out * 1

# Function to calculate social pressure
@njit
def pressure(i, j, aud):
    rows = aud.shape[0]
    cols = aud.shape[1]
    pct_sum = 0
    norm = 0
    for x in range(i):
        active_row = i - x - 1
        left = max(j - (x+1), 0)
        right = min(j + (x+1), cols)
        pct_sum += aud[active_row, left:right+1].mean() / (x+1)**2
        norm += (x+1)**-2
    
    if norm == 0:
        res = 0
    else:
        res = pct_sum / norm
    
    return res

# Calculate pressure from (nextdoor) neighbours
@njit
def neighbour_pressure(i, j, aud):
    cols = aud.shape[1]
    count = 0
    left = 0
    right = 0
    if j != 0:
        left = aud[i, j-1]
        count += 1
    if j != cols -1:
        right = aud[i, j+1]
        count += 1
    return (left + right) / count
        
# Calculate overall pressure score
@njit
def pressure_score(i, j, aud, n_weight):
    return pressure(i, j, aud)*(1 - n_weight) + neighbour_pressure(i, j, aud)*n_weight

# Spontaneous sitting/standing function
@njit
def spontaneous(i, j, aud, dlt, gma):
    rnd = np.random.random()
    if aud[i,j] == 0 and rnd > (1-dlt):
        aud[i,j] = 1
    elif aud[i,j] == 1 and rnd > (1-gma):
        aud[i,j] = 0
    return aud

# Main Code Loop
audience = initial_stand(epsilon, P, T)
Pct_Hold[1] = audience.mean()

for x in range(2, T_steps+1):
    audience_old = audience.copy()
    for i in range(N):
        for j in range(M):
            up_score = pressure_score(i, j, audience_old, N_weight)
            down_score = pressure_score(i, j, 1 -audience_old, N_weight)
            if up_score > Pressure_T and audience_old[i,j] == 0:
                audience[i,j] = 1
            if down_score > Pressure_T and audience_old[i,j] == 1:
                audience[i,j] = 0
            spontaneous(i, j, audience, delta, gamma)
            Pct_Hold[x] = audience.mean()

plt.plot(Pct_Hold)
plt.xlabel("Community Following Rules")
plt.ylabel("Percent Standing")
plt.show()

# %% [markdown]
# # SIR Model

# %% [markdown]
# # Example 1

# %%
import numpy as np
from numpy import exp

import matplotlib.pyplot as plt
from scipy.integrate import odeint

pop_size = 3.3e8
γ = 1 / 18
σ = 1 / 5.2

def F(x, t, R0=1.6):
    """
    Time derivative of the state vector.

        * x is the state vector (array_like)
        * t is time (scalar)
        * R0 is the effective transmission rate, defaulting to a constant

    """
    s, e, i = x

    # New exposure of susceptibles
    β = R0(t) * γ if callable(R0) else R0 * γ
    ne = β * s * i

    # Time derivatives
    ds = - ne
    de = ne - σ * e
    di = σ * e - γ * i

    return ds, de, di

# initial conditions of s, e, i
i_0 = 1e-7
e_0 = 4 * i_0
s_0 = 1 - i_0 - e_0

x_0 = s_0, e_0, i_0

def solve_path(R0, t_vec, x_init=x_0):
    """
    Solve for i(t) and c(t) via numerical integration,
    given the time path for R0.

    """
    G = lambda x, t: F(x, t, R0)
    s_path, e_path, i_path = odeint(G, x_init, t_vec).transpose()

    c_path = 1 - s_path - e_path       # cumulative cases
    return i_path, c_path

t_length = 730
grid_size = 1000
t_vec = np.linspace(0, t_length, grid_size)

R0_vals = np.linspace(1.2, 2.4, 5)
labels = [f'$R0 = {r:.2f}$' for r in R0_vals]
i_paths, c_paths = [], []

for r in R0_vals:
    i_path, c_path = solve_path(r, t_vec)
    i_paths.append(i_path)
    c_paths.append(c_path)
    
def plot_paths(paths, labels, times=t_vec):

    fig, ax = plt.subplots()

    for path, label in zip(paths, labels):
        ax.plot(times, path, label=label)

    ax.legend(loc='upper left')

    plt.show()

plot_paths(i_paths, labels)

plot_paths(c_paths, labels)

#Changing Mitigation

def R0_mitigating(t, r0=5, η=2, r_bar=2.6):
    R0 = r0 * exp(- η * t) + (1 - exp(- η * t)) * r_bar
    return R0

η_vals = 1/5, 1/10, 1/20, 1/50, 1/100
labels = [fr'$\eta = {η:.2f}$' for η in η_vals]

fig, ax = plt.subplots()

for η, label in zip(η_vals, labels):
    ax.plot(t_vec, R0_mitigating(t_vec, η=η), label=label)

ax.legend()
plt.show()

i_paths, c_paths = [], []

for η in η_vals:
    R0 = lambda t: R0_mitigating(t, η=η)
    i_path, c_path = solve_path(R0, t_vec)
    i_paths.append(i_path)
    c_paths.append(c_path)
    
plot_paths(i_paths, labels)

plot_paths(c_paths, labels)

#Ending Lockdown
# initial conditions
i_0 = 20_000 / pop_size
e_0 = 80_000 / pop_size
s_0 = 1 - i_0 - e_0
x_0 = s_0, e_0, i_0

R0_paths = (lambda t: 0.5 if t < 30 else 4,
            lambda t: 0.5 if t < 120 else 4)

labels = [f'scenario {i}' for i in (1, 2)]

i_paths, c_paths = [], []

for R0 in R0_paths:
    i_path, c_path = solve_path(R0, t_vec, x_init=x_0)
    i_paths.append(i_path)
    c_paths.append(c_path)
    
plot_paths(i_paths, labels)

ν = 0.05

paths = [path * ν * pop_size for path in c_paths]
plot_paths(paths, labels)

paths = [path * ν * γ * pop_size for path in i_paths]
plot_paths(paths, labels)

# %% [markdown]
# # Example 2

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Total population, N.
N = 1000
# Initial number of infected and recovered individuals, I0 and R0.
I0, R0 = 1, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0
# Contact rate, beta, and mean recovery rate, gamma, (in 1/days).
beta, gamma = 0.2, 1./10
# A grid of time points (in days)
t = np.linspace(0, 160, 160)

# The SIR model differential equations.
def deriv(y, t, N, beta, gamma):
    S, I, R = y
    dSdt = -beta * S * I / N
    dIdt = beta * S * I / N - gamma * I
    dRdt = gamma * I
    return dSdt, dIdt, dRdt

# Initial conditions vector
y0 = S0, I0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(N, beta, gamma))
S, I, R = ret.T

# Plot the data on three separate curves for S(t), I(t) and R(t)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.plot(t, S/1000, 'b', alpha=0.5, lw=2, label='Susceptible')
ax.plot(t, I/1000, 'r', alpha=0.5, lw=2, label='Infected')
ax.plot(t, R/1000, 'g', alpha=0.5, lw=2, label='Recovered with immunity')
ax.set_xlabel('Time /days')
ax.set_ylabel('Number (1000s)')
ax.set_ylim(0,1.2)
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %% [markdown]
# # Broadcast Model

# %%
import numpy as np 
a = np.array([[0.0,0.0,0.0],[10.0,125.0,150.0],[20.0,225.0,250.0],[30.0,325.0,350.0]]) 
b = np.array([100.0,200.0,300.0])  
   
print ('First Day:')
print (a) 
print ('\n')  
   
print ('Second Day:') 
print (b )
print ('\n')  
   
print ('First Day + Second Day') 
print (a + b)
# Out:
# First Day:
# [[  0.   0.   0.]
#  [ 10. 125. 150.]
#  [ 20. 225. 250.]
#  [ 30. 325. 350.]]
#
#
# Second Day:
# [100. 200. 300.]
#
#
# First Day + Second Day
# [[100. 200. 300.]
#  [110. 325. 450.]
#  [120. 425. 550.]
#  [130. 525. 650.]]

# %% [markdown]
# # Scenario analysis, sensitivity + uncertainty evaluation

# %% [markdown]
# ## Establish baseline parameter sets and or configuration for output scenarios

# %% [markdown]
# # Standing Ovation

# %% [markdown]
# Scenario 1
#
# Scenario 1 is concerned with the location of individuals using the standing ovation model to determine the likelihood of people to continue the ‘standing ovation’ and to put on a mask or any protective equipment to prevent the spread of COVID-19. As previously stated, the more people who are to be wearing masks in a certain city/town, the more likely it is for people to continue that trend and to also wear a mask. A more populated area with more people wearing masks will highlight the importance to protect themselves of the spread of the virus, and thus more people will ‘stand’. Similarly, in the event of a location where there is a smaller population density and more people are not inclined to wear a mask or follow any COVID-19 guidelines, then less people would think it is a necessity to wear a mask due to them copying others who do not wear one.
#
# Scenario 2
#
# Scenario 2 affiliates itself with individuals self-isolating and following the actions of others to stay indoors to protect themselves and others around them. Similar to Scenario 1, this involves individuals obeying the rules and regulations of self-isolating indoors and not participating in any leisure activities or gatherings which are not a necessity. If a person was to notice large gatherings of people outside when there is meant to be country/state-wide isolation, then they may not feel it is as important to follow such rules as others are doing it without consequences occurring. Therefore, if people were to see other individuals and groups outside not abiding by laws, then they themselves will ignore the regulations and move further away from a position to mitigate the spread of the COVID-19 virus.

# %% [markdown]
# # Broadcasting Model

# %% [markdown]
# Scenario 1
#
# The first scenario for the broadcasting model consists highly of the fact that all news and stories heard on the media, is not reliable information. The false news that is spread around about COVID-19 can impact several people who may be ignorant about the facts to do with the virus. This leads to people believing the news and social media platforms, where individuals are stating that the COVID-19 virus is a hoax and it is not in fact a real issue to worry about. The impact that this has is the continuation of individuals to not comply with the rules and regulations that the governments have set, comprising of the self protecting items and maintaining safe distances between one another, which results in more cases being reported due to being exposed to the virus and spreading it onto others.
#
# Scenario 2
#
# Scenario 2 involves the use of statistics and figures shown on the social platforms and media outlets to educate individuals on the drastic impact the virus has had. Due to the extreme nature of the virus, many deaths have been reported and a total of 49 million cases, which results in the advertising of the drastic figures which works towards incentivising to be careful and follow COVID guidelines to stay safe and not risk lives. This is done by individuals not wanting to be caught with the virus and thus, wearing masks and keeping distances from others allows them to be a part of those without the virus - allowing the community to create a safer environment by containing COVID-19.

# %% [markdown]
# ## Perform a basic sensitivity analysis, i.e., identify with parameters are most sensitive/insensitive for the outputs

# %% [markdown]
# # Standing Ovation

# %% [markdown]
# Based on the explanation in the section (5.1) using the first model the ’Standing Ovation’ regarding the transmission and the spread of the virus, in the next step we will be performing a sensitivity analysis to find out which parameter is the more in control to affect the spread of the disease. In our ’Standing Ovation’ model example in how people are influenced by each other when standing ovation occurs and same when ‘wearing a mask’ scenario, here we will assess the scenario of social distancing mandates and levels of masks use, so the more people use the face masks and apply social distancing the transmission rate can be reduced and limited, and the less death rate will occur
#
#
#
# On an experiment done  in a weekly survey from April 14 to May 26, 2020 according to report posted on Pnas.org, A total of n = 925 participants experimenting a realistic scenario in which they had to imagine being in their local grocery store in the fruit section with one other person. randomising whether there was a mandatory or voluntary mask policy in place, and whether or not the other person was wearing a face mask.
#
#
#
#
#
#
#
# interaction policy by others’ mask-wearing behavior: F < 1, not significant]. On the other hand participants who reported wearing a mask frequently in their everyday life were awarded and accepted socially toward other participants who also wear a mask than toward others who do not wear a mask.
#
#
#
# Interaction participant’s mask-wearing behavior by others’ mask-wearing behavior: β = 0.25, P < 0.001).
#
#
#
# This means that people who adhere to the social contract of wearing a mask tend to socially reward and accept each other and ignore others who do not wear a mask.
#
#
#
# irrespective of the mask policy in place. As the number participate who reported being unwilling to wear a mask is increasing under a voluntary policy [77% compliance compared to 96% under a mandatory policy, χ2(1, n = 925) = 71.97, P < 0.001, Vc = 0.279], the negative social evaluation under a voluntary policy (i.e., stigmatization could increase) towards them will decrease
#
#
#
#  In line with this, social labeling increased slightly, as another person wearing a mask was more likely perceived as belonging to a risk group under a voluntary as opposed to a mandatory policy, interaction policy by others’ mask-wearing behavior:
#
# F(1, 921) = 8.88, P = 0.003,
#
# η^2p= 0.010); but they were not regarded as more likely to be infected with COVID-19

# %% [markdown]
# # Broadcast Model

# %% [markdown]
# In this case and based on the result of the standing ovation scenario we will mention below both cases in case of infected and not infectious people and how they affect the spread or containing the virus; The *Total Population of Human* we denote it by N(t) and then divide this into 6 classes:
#
#
#
# S(t): Susceptible Individuals
#
# E1(t): Post stage Exposed Individuals
#
# E2(t): Pre-Stage Exposed Individuals
#
# A(t): Asymptotically infected ind
#
# I1(t): individuals Infected with serious symptoms
#
# I2(t): individuals Infected with mild symptoms
#
# H(t): Hospitalized individuals
#
# R(t): Individuals Recovered from Covid-19
#
#
#
# So,𝑁(𝑡)=𝑆(𝑡)+𝐸(𝑡)+𝐸(𝑡)+𝐼(𝑡)+𝐼(𝑡)+𝐻(𝑡)+𝑅(𝑡)
#
#
#
#
#
# Then assuming  that hospitalised persons are in isolation and not able to with the ’Susceptible Individuals’.
#
# Infectious individuals include E(t), I1(t), and I2(t)
#
# Incubation period of COVID-19 is as long as 2 to 14 days
#
#  In the E1(t) Pre-Stage Exposed people are not infectious but infected
#
# n the E2(t) Post-Stage Exposed individuals are infectious so they have  a risk of transmitting it to others.
#
#
#
# The birth rate and natural death rate are denoted by μ. Susceptible individuals 𝑆(𝑡) can be infected with COVID-19 by effective contact with infectious individuals. We consider that 𝑐 represents the mean number of infectious individuals contacting with 𝑆(𝑡); 𝛽 is the transmission probability and 𝜃 (0 <
#
# 𝜃 < 1) accounts for reduction in transmissibility of 𝐸2(𝑡) compare to 𝐼2(𝑡). Assume that q is the
#
# proportion of 𝐸2(𝑡 )to keep in the quarantine and 𝑝 = 1 − 𝑞 represents the un-quarantined proportion
#
# of post-stage exposed individuals. So, p is infectious. Assume that 𝜃1 (0 < 𝜃1 < 1) accounts for
#
# reduction in transmissibility of 𝐼 (𝑡) compare to 𝐼 (𝑡). Due to opening the hospital, 𝜀 represents the 12
#
# exponential decay of contact rate of infected individuals to susceptible individuals [2]. Let 𝜀1 denotes the minimum proportion of contact rate of infected individuals to susceptible individuals under the measure of opening the hospital.
#
# In the present model, the susceptible individuals get infected of COVID -19 when they come in contact
#
# 𝑐𝛽𝜃𝑝𝐸2 𝑐𝛽𝜃1𝜀1𝐼1 with the infectious individuals 𝐸 (𝑡) , 𝐼 (𝑡) and 𝐼 (𝑡) at the rates ,
#
# 212
#
#
#
#
#
#
#
# and 𝑐𝛽𝜀1𝐼2 𝑁
#
# 𝑁𝑁 respectively. So, the susceptible individuals move to the class 𝐸1(𝑡) at the rate of 𝛼, where
#
#
#
# a= 𝑐𝛽𝜃𝑝𝐸2/N + 𝑐𝛽𝜃1 𝜀1 𝐼1/N + 𝑐𝛽 𝜀1 𝐼1/N
#
#
#
#
#
# Infected individuals 𝐼 (𝑡)) and 𝐼 (𝑡)can be admitted to hospital at the rate of 𝜂 and 𝜂 respectively.
#
#
#
# . We observed that contact rate 𝑐, transmission rate 𝛽and hospitalization rate η1 most important sensitive model parameters. Increasing the contact rate and transmission rate of disease increases the infectious population and increasing the hospitalization rate of infected people, decrease the infectious population

# %% [markdown]
# # Proposed solutions

# %% [markdown]
# ## Discuss potential portfolio of solutions based on your previous analysis

# %% [markdown]
# After analysing the proposed solutions made towards the chosen topic of our course work, the following models comprise of an SRI model, a Broadcast model, and a Standing ovation model. These prove to show the best suitability for our topic, relating strategies to contain Covid-19. Following the modelling approaches chosen, various solutions have been developed from tangible to intangible strategies. These include the integration of face masks, a scheme to categorise individuals and groups from positive cases and those awaiting results, and finally an initiative to educate and inform the general public relating to Covid-19 on all levels on society.
#
# The initial thought and design process in developing these solutions was approached with Many-Model thinking insights, allowing for a more indepth understanding of the contextual background, thus selecting strategies to improve the state of the problem.
#
# It is important to consider each approaches’ aims in model development, the types of data available to them, the preferred treatment of uncertainty, and considering the interactions among agents explicitly. With this criteria, the standing ovation model can be applied as it suggests a likely outcome; if more people wear masks, the more likely it is that others will too. Wearing a mask has continually been encouraged my government bodies and medical professionals. This initiative paired with the standing ovation model shows suitability as it suggests a large peer effect can occur based off the impression of other’s actions. This was an applicable model approach as it suited the purpose of the model, and the types of data available with the initiative. Analogously, depending on the size and shape of the space inhabited, specifically the place of where the individual resides, it will greatly affect the likelihood of deciding to wear a mask. Furthermore, this will positively affect the behaviours and attitudes towards wearing a mask amidst the pandemic.
#
# As before mentioned, the SRI model is used as part of the strategy to contain positive cases through categorisation. In relation to containing Covid-19, this can be utilised by stakeholders in multiple ways and methods. Further as the government and health organisations struggle to find a vaccine, an appropriate method in containing the spread of COVID-19 is to implement the proposed solution, ‘Time Dependent SIR model’. This can be done by tracking 2 times series with the main purpose to find the undetectable cases of COVID-19. This will further be used to calculate the transmission rates, removal rates, and recovering rates, thus aiding government bodies and medical institutions.  For example, where we can precisely predict how (Transmission Rate/day < Recovering Rate/day) and then (reproduction no. will be less than 1) R0 < 1. This could be utilised by recognising the data provided from health organisations, ensuring that the prediction errors per day have decreased and the total predicted number of COVID confirmed cases is done so more precisely.
#
# The final proposed solution of this portfolio in dealing with the pandemic has been approached through a Broadcast model. An initial dilemma and issue concerning Covid-19 was the release of important information towards the general public and businesses. The purpose of a broadcast model is to capture the spread of ideas, rumours and information through television, radio, social media, or internet. It undergoes a process undertaken by sources such as governments, corporations and newspapers when spreading information. This proposed solution intends to effectively broadcast communication about Covid-19 through these models to announce strategies to control the spread of the virus, also to quantify different roles responding to the pandemic to take immediate and protective action. As mentioned beforehand, the Modelling data from the broadcast indicates:
#
# Period 1: I1 = 400,000 = Pbroad · Npop
#
# Period 2: I2 = 700,000 = 400,000 + Pbroad · (Npop – 400,000)
#
# With this data, it is suggested that the different mediums of communication can be utilised in a defining role containing the virus. This is especially evident when considering the probability of the increasing or decreasing the spread is affected by Broadcasting.

# %% [markdown]
# # Reflection on group + individual approach to assignment

# %% [markdown]
# ## Each student should discuss their experiences about working on the project. The document should be no more than 1000 words per group member. It should discuss following key aspects:
#
# - Your contribution in the project
# - Other group members’ contributions
# - What positives do you take from this project? What did you learn from this project?
# - What challenges did you face in this project and how you overcame those?
# - If you are faced with dealing with a real-world problem and need to do some modelling, how would you determine which modelling approach to take. Justify your response.

# %% [markdown]
# ### Group member 1 reflection

# %% [markdown]
# # James Truong
#
# - My Contribution in this project was Section 1, 4 and formatting mainly.
# - From this project I learnt how to use Github and its plugins to the best of my ability.
# - The challenges that I face during the project was communication issues, (e.g. team member not replying for a couple of day. However these issues were resolved by a scheduled group call) and the lossing of a team member halfway through the semester.
# - I would note and determine what factors play a part in deciding which moddel to take e.g. Wearing A Mask , factors would include family,friends, infection rate etc.

# %% [markdown]
# ### Group member 2 reflection

# %% [markdown]
# # Lawrence Roqueza

# %% [markdown]
# The purpose of this reflection report intends to describe the experiences of my individual contributions and the dynamics of group work during the process of completing the various assignments and tasks in the course, Introduction to Human-centered Complex Systems. Serving as a self-assessment, this reports of the collection of skills and challenges, reflecting on the issues faced, becoming a significant influence to improve learning for future projects.
#
# Throughout the course, the modelling assignment was completed as a group. Previously, before starting writing our contributions to the assignment, weekly workshops allowed us to communicate through these meetings, thus deciding on a topic. The first group effort we made for this course which shown effective communication and teamwork was the submission of the modelling assignment draft, sections 1-3. After a scrum meeting, which suited our groups availability, we were able to allocate ourselves into sections for individual contributions. My individual contribution towards this draft was the completion of section 2 which consisted of the contextual information and constructing a diagram via Lucid Charts.
#
# Upon the entire completion of the modelling assignment, my contributions in the project had increased since submitting the draft. One of the obstacles my team faced during the course was losing a member, meaning every team member would have increased workload. One of the contributions were setting up necessary group meetings through our main platform of communication, MS Teams. These extended to my construction of a table document, designed to make group work allocations easier, suiting everyone’s schedule. A last contribution I made for the assignment was completing section 6 as well as editing sections 2 based of the feedback provided.
#
# In regard to the contributions of my group members, everyone worked as a team to carry out individual responsibilities as well as helping out others. The assignment was completed on GitHub, which recommended the member with most programming knowledge to be team leader. Fortunately, our team leader did have experience in this which contributed massively to our group. When members were in situations which limited their work contributions or communications, every member was understanding and empathetic. This extended to certain members even covering workload, something that was retaliated the same. Overall, my group members made essential and substantial contributions in the assignment and in the course generally.
#
# One of the most perceptible learning moments I’ve come across during the course was the introduction to the many different learning tools. This has helped and continue to aid my learning and work. These include the technological platforms such as Lucid charts, GitHub and Medium. These tools have been incredibly useful in both my individual work and working as a group. I have definitely felt a huge help come from these tools which I plan to continually implement in my working methods in the future. Moreover, the completion of the assignment promoted a self-awareness about myself and the world around me concerning my topic.
#
# This project presented more challenges than I anticipated whether on an academic level or concerning group work. A general challenge was learning content through online platforms for 3 hour workshops. This pushed me to act for my time management skills and the way I worked at home, allowing for efficiency and focus when needed. This subject was the first mathematical course I have taken since high school, meaning the statistics and economical aspects was a struggle to grasp at first. Whenever I was faced with a difficult situation as such, my group mates and tutor were always available to take the time to explain. However an obstacle which required the most work was being able to create a group meeting schedule outside of workshops. Overcoming this required initiative. We understood that this wouldn’t work as it normally would, meaning we had to create a new way to do this. This was shown in the documents I made to self-allocate ourselves into sections, allowing us to clarify over text.
#
# This course taught me to process the world around me through a modelling approach, and to determine which approach to take. A model can capture a shared understanding of system processes and can help people to manage disagreements. There are 5 common approaches to developing models, however when choosing the type of modelling approach it is important to consider the purpose of the model, the types of data available to develop and specify the model, as well as the model users and the requirements for scales and formats of model output. These are Systems Dynamics, Bayesian Networks, Couple Component Models, Agent-Based Models and Knowledge-Based Models. It is important to consider each approaches’ aims in model development, the types of data available to them, the preferred treatment of uncertainty, and considering the interactions among agents explicitly.

# %% [markdown]
# ### Group member 3 reflection

# %% [markdown]
# # Harrison Andrew

# %% [markdown]
# During this reflection portfolio, in my first experiences of undertaking Human-centred Complex Systems as a subject, I noticed the serve differences it had compared with the other subjects i have previously completed or am also completing currently. The introduction of a completely new platform called ‘Github’ proved to be very challenging to grasp the basic concepts of, even after attempting multiple times. Due to this, a heavy reliance on teamwork and leadership was to come about. The project overall taught me many lessons in relation to workload, organisation, and reliance.
#
# My Contribution
#
# The contribution that I had brought to the team begins with the knowledge that I took in from the several weeks of workshops that I attended, to allow myself to gain as much information which could be used to further the project's completion status. The team communication was very important, where myself and the rest of the group was to talk to each other through our Microsoft Teams group chat, to order the assignment and figure out which tasks were assigned to who. In the final project, I aided in completing it through my efforts on the 5th section. This consisted of the scenarios which were built around using the 3 models we chose in real life situations.
#
# Teams Contribution
#
# The team's contribution was very significant as we are all in fact, accountable for one another. As aforementioned, as a team we were all inclined to talk together about the project and to assign everyone to tasks for its completion. This was done through the group chat that was established.
#
# What positives do you take from this project? What did you learn from this project?
#
# The positives that I can take with me from this project is the sheer volume of information that can be adapted into many different situations with unique problems. Using real life problems to gain a better understanding of course content allows for the ease in learning it to the best of my potential, where I can imagine those problems and assign it with a model. I can also take away the importance of teamwork, which is the glue that sticks value onto the project, as without it, the team would crumble and the work would have no flow and wouldn't be appealing to read.
#
# What challenges did you face in this project and how you overcame those?
#
# The challenges that I faced in this project was the multiple losses of work that I had to deal with due to old technology that I was using. In order to work around this, I made sure after I had lost my work a few times, to repeatedly save the files as losing the work and being set back was an extreme detriment to my work progress. Another challenge that we faced as a team was the loss of a teammate. Due to a change in desire to complete the course he was currently in, midway through the semester he left and our team was down 1 person to finish the project. To compensate for this, we all decided to take a larger workload ourselves and finish off the project without complaining and wasting time.
#
# If you are faced with dealing with a real-world problem and need to do some modelling, how would you determine which modelling approach to take. Justify your response.
#
# If I were to be faced with a real-world problem, I would empathise and imagine myself in somebody else’s position and pretend I was to model as they would. What I have taken out of this subject is most of the models are shaped around the majority of what would occur, as they are very rational in my opinion. Due to this, I would imagine the probability of such an event occurring over another, and thus, apply whatever model would suit the best for that scenario.

# %% [markdown]
# ### Group member 4 reflection

# %% [markdown]
# # Ali Khalife

# %% [markdown]
# For this assignment my group
#
# Lawrence Roqueza
#
# Harrison Andrew
#
# James Truong
#
#  along with myself had to create a GitHub file which was mainly on the group’s leader account James Turong who created it, forked it and shared into UTS Canvas for us to contribute with him in creating the content of the file, that contained several points about the topic “Implementing Strategies to Contain Covid-19 spread ” where my contribution in the content was using one of the models (SRI model and the) being used to address the issue,  describing its statistical implementation and function on how it can be applied in our case
#
# As well my contribution was to how we can use data sources and formulas in the (Broadcast model) explaining how media can play a vital role containing the virus.
#
#
#
# I also learned many key points along the way in achieving this goal, I learned what a model is and why do we use it instead of using another form of solution for the given problem and learned how to use the real or hypothetical data sources in these conceptual models.
#
#
#
# My group have created the rest of the models and all the explanation related from A to Z, where very detailed report was used from researching in the media how the problem was addressed to identifying the stakeholders involved in the process to explaining the models used from to the conceptual model such as the Standing Ovation and broadcasting model based on the super market of models in our class content, discussing how these models can be used to contain/stop the issue mentioned (Covid-19) and to finally proposing a solution based on what was suggested.
#
#
#
# Personally, I learnt a lot from this project, starting from team work and the progressive work for our team members along with giving feedback to each other for improvements, I also learnt how to use GitHub (creating repository, files, editing, pushing from *‘Jupyter Lab’*, committing changes and sharing )which was one of my main goals and concerns as an IS student which is an essential skill to become an IS professional in the future
#
#
#
# One of the main challenges was using *‘Jupyter Lab’* and installing Git on my machine where I had to ask for help, and with the help of my subject tutor Dr. Juan in a one on one Zoom session he was able to install all the related software tools required like the Jupyter Lab and guided me how to do it and get me started.
#
#
#
# If in the near future dealing with a real-world problem and need to do some modelling, I now then feel confident in using the modelling techniques and if asked which type of modelling  would I take, then this will depend on the kind of situation, but in identifying the approach, and after what l learnt I would take system type and boundaries into consideration and  then use predictions approach based analysis of models and their functions where it has proven it’s efficiency and accuracy especially for examples given that we went through in our lectures like, the *Broadcast*, *Diffusion*, *Contagion*, and *SIR* models, and especially standing ovation and Broadcast that I and my colleague Harrison Andrew we used in this assignment in parts 5.1 and 5.2.
